# %%
phone_number = 546234
print(phone_number)
# Out:
# 546234
# 546234

# %%
name="Phitron"
print(name)
# Out:
# Phitron

# %%
age=20  
hight =5.9
name = "Phitron"
is_student = True
print(type (age),type(hight),type(name),type(is_student))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
x=6; y=4
print(x,y)
sum = x+y
sub = x-y
mul = x*y
div = x/y
print(sum,sub,mul,div)
# Out:
# 6 4
# 10 2 24 1.5

# %%
x=4 ; y=6
Greter = x>y
Less = x<y
print(Greter,Less)
# Out:
# False True

# %% [markdown]
# Problem

# %%
inp = input ()
number = inp.split()
x=int(number[0])
y=int(number[1])
last_digit_X=x%10
last_digit_Y=y%10
sum = last_digit_X + last_digit_Y
print(sum)
# Out:
# 5

# %%
raining = True
muddy = True

if raining == True:
    print("Take an umbrella")
    if muddy== True:
        print("Wear boots")
    else:
        print("Wear shoes")
else:
    print("No need to take an umbrella")
# Out:
# Take an umbrella
# Wear boots
